# %%
import os
import re
import torch
import numpy as np
import tifffile as tiff
from torch.utils.data import Dataset, random_split, DataLoader
from torchvision.transforms.v2.functional import normalize

# %%
from google.colab import drive
drive.mount('/content/drive') # Mount Google Drive
path = "/content/drive/MyDrive/Colab Notebooks/Sen2MTC_FULL_3v1_norm.pt"
data = torch.load(path, map_location="cpu")

class PrecomputedSen2MTC(Dataset):
    def __init__(self, data_list):
        # data_list is a list of dicts:
        # [{"cloudy_seq": tensor, "clean": tensor}, ...]
        self.data = data_list

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        return {
            "cloudy_seq": item["cloudy_seq"],
            "clean": item["clean"]
        }

def collate_mt(batch):
    # batch: list of {"cloudy_seq":..., "clean":...}

    cloudy = [b["cloudy_seq"] for b in batch]   # list of (T,C,H,W)
    clean  = [b["clean"]      for b in batch]   # list of (C,H,W)

    cloudy = torch.stack(cloudy, dim=0)    # (B,T,C,H,W)
    clean  = torch.stack(clean,  dim=0)    # (B,C,H,W)

    return {
        "cloudy_seq": cloudy,
        "clean": clean
    }


train_set = PrecomputedSen2MTC(data["train"])
val_set   = PrecomputedSen2MTC(data["val"])
test_set  = PrecomputedSen2MTC(data["test"])

train_loader = DataLoader(train_set, batch_size=16,
                          shuffle=True, collate_fn=collate_mt)

val_loader   = DataLoader(val_set,   batch_size=16,
                          shuffle=False, collate_fn=collate_mt)

test_loader  = DataLoader(test_set,  batch_size=16,
                          shuffle=False, collate_fn=collate_mt)


batch = next(iter(train_loader))

print(batch["cloudy_seq"].shape)   # (B,T,C,H,W)
print(batch["clean"].shape)        # (B,C,H,W)
# Out:
# Mounted at /content/drive
# torch.Size([16, 3, 4, 128, 128])
# torch.Size([16, 4, 128, 128])

# %% [markdown]
# Multiencoder (3 versus 1)

# %%
import torch.nn as nn
import torch.nn.functional as F

# structure ok
class ResidualBlock(nn.Module):
    """
    Small residual conv block:
    in -> Conv -> GN -> SiLU -> Conv -> GN -> +skip
    """
    def __init__(self, in_channels, out_channels, num_groups=8):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.gn1   = nn.GroupNorm(num_groups=min(num_groups, out_channels), num_channels=out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.gn2   = nn.GroupNorm(num_groups=min(num_groups, out_channels), num_channels=out_channels)
        self.silu   = nn.SiLU(inplace=True)

        # if channel dims change, use 1*1 conv for skip
        if in_channels != out_channels:
            self.skip = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        else:
            self.skip = nn.Identity()

    def forward(self, x):
        identity = self.skip(x)
        out = self.conv1(x)
        out = self.gn1(out)
        out = self.silu(out)
        out = self.conv2(out)
        out = self.gn2(out)
        out = out + identity
        out = self.silu(out)
        return out

class CloudEncoder(nn.Module):
    """
    Cloud encoder based on CNN.

    Input:
        x: (B, in_channels, H, W), normalize required

    Output:
        feat: (B, C_lowres, H_down, W_down)  spatial cloud features
        z:    (B, latent_dim)               global embedding
    """
    def __init__(
        self,
        in_channels = 4,
        base_channels = 32,
        num_stages = 3,
        latent_dim = 128,
        num_groups = 8,
    ):
        super().__init__()

        self.in_channels = in_channels
        self.base_channels = base_channels
        self.num_stages = num_stages
        self.latent_dim = latent_dim

        layers = []

        # Initial conv to get to base_channels
        layers.append(
            nn.Sequential(
                nn.Conv2d(in_channels, base_channels, kernel_size=3, padding=1),
                nn.GroupNorm(num_groups=min(num_groups, base_channels), num_channels=base_channels),
                nn.SiLU(inplace=True),
            )
        )

        in_ch = base_channels
        channels = [base_channels * (2 ** i) for i in range(num_stages)]

        # Residual + downsample stages
        self.down_blocks = nn.ModuleList()
        self.downsamples = nn.ModuleList()

        for out_ch in channels:
            self.down_blocks.append(ResidualBlock(in_ch, out_ch, num_groups=num_groups))
            # stride-2 conv for downsampling
            self.downsamples.append(
                nn.Conv2d(out_ch, out_ch, kernel_size=4, stride=2, padding=1)
            )
            in_ch = out_ch

        # A final residual block at lowest resolution
        self.final_block = ResidualBlock(in_ch, in_ch, num_groups=num_groups)

        # Register first stem as single module for clarity
        self.stem = layers[0]

        # Projection to latent space
        self.proj = nn.Linear(in_ch, latent_dim)

    def forward(self, x: torch.Tensor):
        """
        x: (B, C, H, W)

        returns:
            feat: (B, C_final, H_down, W_down)  spatial feature map
            z:    (B, latent_dim)               global vector
        """
        # Stem
        h = self.stem(x)  # (B, base_channels, H, W)

        # Downsampling stages
        for block, down in zip(self.down_blocks, self.downsamples):
            h = block(h)
            h = down(h)  # spatial size halves each time

        # Final block
        h = self.final_block(h)

        # 1) spatial feature map (we keep it as-is)
        feat = h  # (B, C_final, H_down, W_down)

        # 2) global average pooling -> vector
        pooled = F.adaptive_avg_pool2d(h, output_size=1).squeeze(-1).squeeze(-1)

        # 3) project to latent_dim
        z = self.proj(pooled)  # (B, latent_dim)

        return feat, z

# %%
import torch.nn as nn
import torch.nn.functional as F

class MultiTemporalCloudEncoder(nn.Module):
    """
    Wraps a single-image CloudEncoder to handle a sequence of T cloudy images with
    a learned temporal fusion to reduce hallucination risk.

    Input:
        cloudy_seq: (B, T, C, H, W)
    Output:
        feat_agg: (B, C_deep, H_d, W_d)   # aggregated spatial features
        z_agg:    (B, latent_dim)        # aggregated global vector
    """
    def __init__(self, base_encoder: CloudEncoder, T: int = 3):
        super().__init__()
        self.base_encoder = base_encoder
        self.T = T

        # Small MLP to score each timestep using the latent vector
        lat_dim = getattr(base_encoder, 'latent_dim', 128)
        hidden = max(lat_dim // 2, 32)
        self.score_mlp = nn.Sequential(
            nn.Linear(lat_dim, hidden),
            nn.SiLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, cloudy_seq: torch.Tensor):
        B, T, C, H, W = cloudy_seq.shape
        assert T == self.T, f"Expected T={self.T}, got {T}"

        # (B,T,C,H,W) -> (B*T,C,H,W)
        x_flat = cloudy_seq.view(B * T, C, H, W)

        # apply your existing single-image encoder
        feat_flat, z_flat = self.base_encoder(x_flat)
        # feat_flat: (B*T, C_deep, H_d, W_d)
        # z_flat:    (B*T, latent_dim)

        C_deep = feat_flat.shape[1]
        H_d    = feat_flat.shape[2]
        W_d    = feat_flat.shape[3]
        latent_dim = z_flat.shape[1]

        # reshape back to (B,T,...)
        feat = feat_flat.view(B, T, C_deep, H_d, W_d)
        z    = z_flat.view(B, T, latent_dim)

        # learned temporal weights from z
        scores = self.score_mlp(z)                 # (B,T,1)
        weights = F.softmax(scores, dim=1)         # (B,T,1)

        # weighted aggregation
        w_feat = weights.view(B, T, 1, 1, 1)
        feat_agg = (w_feat * feat).sum(dim=1)      # (B, C_deep, H_d, W_d)
        w_z = weights                               # (B,T,1)
        z_agg = (w_z * z).sum(dim=1)               # (B, latent_dim)

        return feat_agg, z_agg

# %%
class ForwardDiffusion_traditional(nn.Module):
    """
    Standard DDPM-style forward diffusion on CLEAN only,
    but keeps the (clean, cloudy, t) signature for compatibility.
    """
    def __init__(self, T=500, beta_start=1e-4, beta_end=0.02):
        super().__init__()
        self.T = T

        betas = torch.linspace(beta_start, beta_end, T)
        alphas = 1.0 - betas
        alphas_cumprod = torch.cumprod(alphas, dim=0)

        self.register_buffer("betas", betas)
        self.register_buffer("alphas", alphas)
        self.register_buffer("alphas_cumprod", alphas_cumprod)

    def sample_t(self, batch_size, device):
        return torch.randint(0, self.T, (batch_size,), device=device)

    def forward(self, clean, cloudy, t):
        """
        clean:  (B, C, H, W)
        cloudy: unused, kept only for API compatibility
        t:      (B,) integer timesteps
        """
        B = clean.shape[0]
        noise = torch.randn_like(clean)

        alpha_bar_t = self.alphas_cumprod[t].view(B, 1, 1, 1)
        x_t = torch.sqrt(alpha_bar_t) * clean + torch.sqrt(1 - alpha_bar_t) * noise
        return x_t, noise, None  # mu_t not used anymore


class ForwardDiffusion(nn.Module):
    """
    Liu-style forward:
        x_t = (1-位_t)*clean + 位_t*cloudy + 蟽_t * 蔚
    """
    def __init__(self, T=500, sigma_min=0.01, sigma_max=0.4):
        super().__init__()
        self.T = T

        sigmas = torch.linspace(sigma_min, sigma_max, T)
        lambdas = torch.linspace(0.0, 1.0, T)

        self.register_buffer("sigmas", sigmas)     # (T,)
        self.register_buffer("lambdas", lambdas)   # (T,)

    def sample_t(self, batch_size, device):
        return torch.randint(0, self.T, (batch_size,), device=device)

    def forward(self, clean, cloudy, t):
        """
        clean, cloudy: (B,C,H,W)
        t: (B,) int timesteps
        Returns:
            x_t:  noisy sample
            eps:  noise used
            mu_t: clean/cloudy mean BEFORE noise
        """
        B = clean.shape[0]
        eps = torch.randn_like(clean)

        sigma_t  = self.sigmas[t].view(B, 1, 1, 1)
        lambda_t = self.lambdas[t].view(B, 1, 1, 1)

        mu_t = (1.0 - lambda_t) * clean + lambda_t * cloudy
        x_t  = mu_t + sigma_t * eps

        return x_t, eps, mu_t

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


# ---------------------------------------------------------------------
# 1. Simple sinusoidal timestep embedding
# ---------------------------------------------------------------------
def timestep_embedding(t, dim):
    half = dim // 2
    freqs = torch.exp(
        torch.arange(half, dtype=torch.float32, device=t.device)
        * (-torch.log(torch.tensor(10000.0)) / (half - 1))
    )
    args = t[:, None].float() * freqs[None]
    emb = torch.cat([torch.sin(args), torch.cos(args)], dim=-1)
    return emb


# ---------------------------------------------------------------------
# 2. Basic ResNet block (Conv-Norm-Act-Conv-Norm-Act)
# ---------------------------------------------------------------------
class ResBlock(nn.Module):
    def __init__(self, in_ch, out_ch, time_emb_dim, cond_dim):
        super().__init__()
        self.time_dense = nn.Linear(time_emb_dim, out_ch)
        self.cond_dense = nn.Linear(cond_dim, out_ch)

        self.conv1 = nn.Conv2d(in_ch, out_ch, 3, padding=1)
        self.conv2 = nn.Conv2d(out_ch, out_ch, 3, padding=1)
        self.norm1 = nn.GroupNorm(8, out_ch)
        self.norm2 = nn.GroupNorm(8, out_ch)
        self.act = nn.SiLU()

        self.shortcut = nn.Conv2d(in_ch, out_ch, 1) if in_ch != out_ch else nn.Identity()

    def forward(self, x, t_emb, c_emb):
        """
        x:     (B, C, H, W)
        t_emb: (B, time_emb_dim)
        c_emb: (B, cond_dim)
        """
        h = self.conv1(x)
        h = self.norm1(h)
        h = self.act(h)

        t_added = self.time_dense(t_emb)[:, :, None, None]
        c_added = self.cond_dense(c_emb)[:, :, None, None]
        h = h + t_added + c_added

        h = self.conv2(h)
        h = self.norm2(h)
        h = self.act(h)

        return h + self.shortcut(x)



# ---------------------------------------------------------------------
# 3. Minimal UNet for 4 channel diffusion
# ---------------------------------------------------------------------
class SmallUNet4C(nn.Module):
    def __init__(
        self,
        in_channels=4,
        out_channels=4,
        base_channels=64,
        time_emb_dim=256,
        cond_dim=128,
        max_T=750
    ):
        super().__init__()
        self.max_T = max_T
        # time embedding MLP
        self.time_mlp = nn.Sequential(
            nn.Linear(time_emb_dim, time_emb_dim),
            nn.SiLU(),
            nn.Linear(time_emb_dim, time_emb_dim),
        )

        # cloud embedding MLP
        self.cond_mlp = nn.Sequential(
            nn.Linear(cond_dim, time_emb_dim),
            nn.SiLU(),
            nn.Linear(time_emb_dim, time_emb_dim),
        )

        # ---------- Down ----------
        self.conv_in = nn.Conv2d(in_channels, base_channels, 3, padding=1)

        self.down1 = ResBlock(base_channels, base_channels * 2, time_emb_dim, time_emb_dim)
        self.down2 = ResBlock(base_channels * 2, base_channels * 4, time_emb_dim, time_emb_dim)

        self.pool = nn.MaxPool2d(2)

        # ---------- Middle ----------
        self.mid = ResBlock(base_channels * 4, base_channels * 4, time_emb_dim, time_emb_dim)

        # ---------- Up ----------
        self.up1 = ResBlock(base_channels * 4 + base_channels * 4, base_channels * 2, time_emb_dim, time_emb_dim)
        self.up2 = ResBlock(base_channels * 2 + base_channels * 2, base_channels, time_emb_dim, time_emb_dim)

        self.conv_out = nn.Conv2d(base_channels, out_channels, 3, padding=1)

    def forward(self, x, t, z_cloud):
        # t: (B,)
        if t.ndim == 0:
            t = t.unsqueeze(0)

        t = t.float() / (self.max_T - 1)     # normalize to [0,1]
        t_emb = timestep_embedding(t, self.time_mlp[0].in_features)
        t_emb = self.time_mlp(t_emb)

        c_emb = self.cond_mlp(z_cloud)

        # Down
        x1 = self.conv_in(x)
        x2 = self.down1(x1, t_emb, c_emb)
        x3 = self.pool(x2)
        x3 = self.down2(x3, t_emb, c_emb)

        # Middle
        xm = self.mid(x3, t_emb, c_emb)

        # Up
        u1 = torch.cat([xm, x3], dim=1)
        u1 = self.up1(u1, t_emb, c_emb)

        u2 = F.interpolate(u1, scale_factor=2, mode="nearest")
        u2 = torch.cat([u2, x2], dim=1)
        u2 = self.up2(u2, t_emb, c_emb)

        out = self.conv_out(u2)
        return out


class CloudConditionedUNet_4C(nn.Module):
    def __init__(self, in_channels=4, out_channels=4, latent_dim=128, max_T=750):
        super().__init__()

        self.unet = SmallUNet4C(
            in_channels=in_channels,
            out_channels=out_channels,
            cond_dim=latent_dim,
            max_T=max_T
        )

    def forward(self, x_t, t, z_cloud):
        eps_pred = self.unet(x_t, t, z_cloud)
        return eps_pred

# %%
def edm_preconditioning(sigma, sigma_data=1.0):
    """
    Given noise level sigma (shape [B]), compute EDM-style
    preconditioning coefficients.

    Returns:
        c_in, c_skip, c_out, c_noise
    each broadcastable to image tensors.
    """
    # make sure sigma has shape [B, 1, 1, 1]
    if sigma.ndim == 1:
        sigma = sigma.view(-1, 1, 1, 1)

    sigma2 = sigma ** 2
    sd2 = sigma_data ** 2

    # input scaling
    c_in = 1.0 / torch.sqrt(sd2 + sigma2)

    # skip connection weight
    c_skip = sd2 / (sd2 + sigma2)

    # output scaling
    c_out = (sigma * sigma_data) / torch.sqrt(sd2 + sigma2)

    # extra noise embedding (optional, for a small MLP)
    c_noise = 0.25 * torch.log(sigma)

    return c_in, c_skip, c_out, c_noise

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# base encoder config
in_channels = 4
base_channels = 32
num_stages = 3
latent_dim = 256

base_encoder = CloudEncoder(
    in_channels=in_channels,
    base_channels=base_channels,
    num_stages=num_stages,   # or 3, whatever you used
    latent_dim=latent_dim
).to(device)

cloud_encoder = MultiTemporalCloudEncoder(base_encoder, T=3).to(device)
forwarder = ForwardDiffusion(T=750).to(device)

# Feature channels after encoder final block
feat_channels = base_channels * (2 ** (num_stages - 1))  # e.g., 64 for num_stages=2
# F_in channels: 4 noisy + 3*4 cloudy sequence + feat_channels
f_in_channels = 4 + 3 * in_channels + feat_channels

# We keep out_channels=4 for noise prediction

denoiser = CloudConditionedUNet_4C(
    in_channels=f_in_channels,
    out_channels=4,
    latent_dim=latent_dim,
    max_T=750
).to(device)

# %%
def normalize_tensor(x):
    """Pass-through because inputs are already normalized upstream."""
    return x

# %%
@torch.no_grad()
def sampler(
    cloudy_seq: torch.Tensor,
    cloud_encoder,
    denoiser,
    forwarder,
    num_steps: int = 100,
    device=None,
):
    if device is None:
        device = cloudy_seq.device
    cloudy_seq = normalize_tensor(cloudy_seq.to(device))   # (B,3,4,H,W)
    B, T, C, H, W = cloudy_seq.shape

    cloudy_ref = cloudy_seq[:, 0]                          # use first frame
    cloud_feat, z_cloud = cloud_encoder(cloudy_seq)
    feat_up = F.interpolate(
        cloud_feat,
        size=(H, W),
        mode='bilinear',
        align_corners=False,
    )
    cloudy_seq_flat = cloudy_seq.view(B, -1, H, W)         # (B,12,H,W)

    times = torch.linspace(forwarder.T - 1, 0, steps=num_steps + 1, device=device).long()

    t_start = times[0]
    sigma_start = forwarder.sigmas[t_start].view(1, 1, 1, 1).to(device)
    x_t = cloudy_ref + sigma_start * torch.randn_like(cloudy_ref)

    for i in range(num_steps):
        t_now = times[i]
        t_next = times[i + 1]

        lambda_now = forwarder.lambdas[t_now].view(1, 1, 1, 1).to(device)
        lambda_next = forwarder.lambdas[t_next].view(1, 1, 1, 1).to(device)

        sigma_now = forwarder.sigmas[t_now].to(device)
        sigma_next = forwarder.sigmas[t_next].to(device)

        c_in, c_skip, c_out, c_noise = edm_preconditioning(
            sigma_now.expand(B), sigma_data=1.0
        )

        x_t_scaled = c_in * x_t
        F_in = torch.cat([x_t_scaled, cloudy_seq_flat, feat_up], dim=1)  # (B,?,H,W)
        assert F_in.shape[1] == denoiser.unet.conv_in.in_channels,             f"F_in channels {F_in.shape[1]} != denoiser expects {denoiser.unet.conv_in.in_channels}. Rerun cell 12 to reinit denoiser."

        t_batch = t_now.expand(B)
        F_out = denoiser(F_in, t_batch, z_cloud)        # (B,4,H,W)

        x0_pred = c_skip * x_t + c_out * F_out          # (B,4,H,W)

        mu_now  = (1.0 - lambda_now)  * x0_pred + lambda_now  * cloudy_ref
        mu_next = (1.0 - lambda_next) * x0_pred + lambda_next * cloudy_ref

        deviation = x_t - mu_now
        noise_scale = sigma_next / (sigma_now + 1e-8)

        x_t = mu_next + noise_scale * deviation

    return x_t

# %% [markdown]
# Start Here: The model image generation part

# %%
import torch
import os

# === CHANGE THESE TO YOUR ACTUAL PATHS ===
# If you saved them in the current working directory:
ENC_CKPT = "/content/drive/MyDrive/Colab Notebooks/cloud_enc_7e_MiniData_forward refined.pth"
DEN_CKPT = "/content/drive/MyDrive/Colab Notebooks/denoiser_7e_MiniData_forward refined.pth"

# If you moved them to Drive, it might be something like:
# ENC_CKPT = "/content/drive/MyDrive/Colab Notebooks/cloud_enc_7e_MiniData_forward refined.pth"
# DEN_CKPT = "/content/drive/MyDrive/Colab Notebooks/denoiser_7e_MiniData_forward refined.pth"

print("Loading encoder from:", ENC_CKPT)
cloud_encoder.load_state_dict(torch.load(ENC_CKPT, map_location=device))

print("Loading denoiser from:", DEN_CKPT)
denoiser.load_state_dict(torch.load(DEN_CKPT, map_location=device))

cloud_encoder.to(device).eval()
denoiser.to(device).eval()

print("Models loaded and set to eval().")
# Out:
# Loading encoder from: /content/drive/MyDrive/Colab Notebooks/cloud_enc_7e_MiniData_forward refined.pth
# Loading denoiser from: /content/drive/MyDrive/Colab Notebooks/denoiser_7e_MiniData_forward refined.pth
# Models loaded and set to eval().

# %%
def to_vis(img):
    """
    Convert (4,H,W) or (3,H,W) to (H,W,3) for visualization.

    - If the image has 4 channels, drop the 4th (NIR)
    - Normalize to [0,1] for matplotlib
    """
    import torch
    import numpy as np

    # if sampler gives (T,4,H,W) or (T,3,H,W)
    if img.ndim == 4:
        img = img.mean(dim=0)

    if img.ndim != 3:
        raise ValueError(f"Expected 3 dims, got {img.ndim}")

    # Convert to numpy RGB
    x = img[:3].detach().cpu().numpy()   # keep first 3 channels (RGB)

    # (C,H,W) → (H,W,C)
    x = x.transpose(1, 2, 0)

    # Normalize for display
    x = x - x.min()
    x = x / (x.max() + 1e-6)

    return x

# %%
import os
import matplotlib.pyplot as plt
import torch



cloud_encoder.to(device).eval()
denoiser.to(device).eval()

base_out_dir = "./gen_results"       # top folder for everything
os.makedirs(base_out_dir, exist_ok=True)

splits = [
    ("val",  val_loader),
    ("test", test_loader),
]

num_steps = 750        # your choice

for split_name, loader in splits:
    out_dir = os.path.join(base_out_dir, split_name)
    os.makedirs(out_dir, exist_ok=True)

    print(f"Generating for split: {split_name}, saving to {out_dir}")
    idx_global = 0

    with torch.no_grad():
        for batch in loader:
            cloudy_seq = batch["cloudy_seq"].to(device)   # (B, T, 4, H, W)
            clean      = batch["clean"].to(device)        # (B, 4, H, W)

            # run your sampler EXACTLY like in your test code
            x0 = sampler(
                cloudy_seq=cloudy_seq,
                cloud_encoder=cloud_encoder,
                denoiser=denoiser,
                forwarder=forwarder,
                num_steps=num_steps,
                device=device,
            )                                             # (B,4,H,W)

            B = cloudy_seq.shape[0]
            cloudy_ref = cloudy_seq[:, 0]                 # (B,4,H,W) – first frame

            for i in range(B):
                cloudy_vis = to_vis(cloudy_ref[i])
                clean_vis  = to_vis(clean[i])
                pred_vis   = to_vis(x0[i])

                base = f"{split_name}_{idx_global:05d}"

                plt.imsave(os.path.join(out_dir, f"{base}_cloudy.png"), cloudy_vis)
                plt.imsave(os.path.join(out_dir, f"{base}_clean.png"),  clean_vis)
                plt.imsave(os.path.join(out_dir, f"{base}_pred.png"),   pred_vis)

                idx_global += 1

    print(f"[{split_name}] Saved {idx_global} triplets into '{out_dir}'.")
# Out:
# Generating for split: val, saving to ./gen_results/val
# [val] Saved 2050 triplets into './gen_results/val'.
# Generating for split: test, saving to ./gen_results/test
# [test] Saved 2051 triplets into './gen_results/test'.

# %%
# !zip -r gen_results.zip gen_results
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   adding: gen_results/test/test_01018_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01271_clean.png (stored 0%)
#   adding: gen_results/test/test_00629_clean.png (deflated 0%)
#   adding: gen_results/test/test_00537_clean.png (deflated 0%)
#   adding: gen_results/test/test_01003_clean.png (deflated 0%)
#   adding: gen_results/test/test_02013_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01936_pred.png (deflated 0%)
#   adding: gen_results/test/test_01604_pred.png (deflated 0%)
#   adding: gen_results/test/test_01425_pred.png (deflated 0%)
#   adding: gen_results/test/test_01303_pred.png (deflated 0%)
#   adding: gen_results/test/test_00698_pred.png (deflated 0%)
#   adding: gen_results/test/test_00574_clean.png (deflated 0%)
#   adding: gen_results/test/test_00324_pred.png (deflated 0%)
#   adding: gen_results/test/test_01700_clean.png (stored 0%)
#   adding: gen_results/test/test_01190_pred.png (deflated 0%)
#   adding: gen_results/test/test_00582_pred.png (deflated 0%)
#   adding: gen_results/test/test_01015_clean.png (deflated 0%)
#   adding: gen_results/test/test_01108_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01988_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00416_pred.png (deflated 0%)
#   adding: gen_results/test/test_01060_pred.png (stored 0%)
#   adding: gen_results/test/test_00002_pred.png (deflated 0%)
#   adding: gen_results/test/test_01531_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00632_clean.png (stored 0%)
#   adding: gen_results/test/test_01153_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01148_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00382_clean.png (stored 0%)
#   adding: gen_results/test/test_00636_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00708_pred.png (stored 0%)
#   adding: gen_results/test/test_00059_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01745_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00675_pred.png (stored 0%)
#   adding: gen_results/test/test_01289_clean.png (deflated 0%)
#   adding: gen_results/test/test_01225_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00797_clean.png (stored 0%)
#   adding: gen_results/test/test_00147_clean.png (deflated 0%)
#   adding: gen_results/test/test_01460_clean.png (deflated 0%)
#   adding: gen_results/test/test_00919_clean.png (stored 0%)
#   adding: gen_results/test/test_01020_pred.png (deflated 0%)
#   adding: gen_results/test/test_01021_clean.png (deflated 0%)
#   adding: gen_results/test/test_00150_clean.png (deflated 0%)
#   adding: gen_results/test/test_01992_pred.png (deflated 0%)
#   adding: gen_results/test/test_01019_clean.png (deflated 0%)
#   adding: gen_results/test/test_00819_clean.png (deflated 0%)
#   adding: gen_results/test/test_00489_pred.png (deflated 0%)
#   adding: gen_results/test/test_01425_clean.png (deflated 0%)
#   adding: gen_results/test/test_00321_pred.png (deflated 0%)
#   adding: gen_results/test/test_01296_pred.png (deflated 0%)
#   adding: gen_results/test/test_01953_clean.png (deflated 0%)
#   adding: gen_results/test/test_00054_pred.png (deflated 0%)
#   adding: gen_results/test/test_00601_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00134_pred.png (deflated 0%)
#   adding: gen_results/test/test_01225_pred.png (deflated 0%)
#   adding: gen_results/test/test_00415_pred.png (deflated 0%)
#   adding: gen_results/test/test_01826_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01982_pred.png (deflated 0%)
#   adding: gen_results/test/test_01162_pred.png (deflated 0%)
#   adding: gen_results/test/test_00442_clean.png (stored 0%)
#   adding: gen_results/test/test_02014_pred.png (deflated 0%)
#   adding: gen_results/test/test_00103_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00320_pred.png (deflated 0%)
#   adding: gen_results/test/test_01742_pred.png (deflated 0%)
#   adding: gen_results/test/test_01201_clean.png (deflated 0%)
#   adding: gen_results/test/test_00917_clean.png (deflated 0%)
#   adding: gen_results/test/test_01136_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00267_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00260_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00636_clean.png (deflated 0%)
#   adding: gen_results/test/test_02015_pred.png (deflated 0%)
#   adding: gen_results/test/test_01502_pred.png (deflated 0%)
#   adding: gen_results/test/test_00717_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00678_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01656_clean.png (deflated 0%)
#   adding: gen_results/test/test_00215_pred.png (deflated 0%)
#   adding: gen_results/test/test_01654_pred.png (deflated 0%)
#   adding: gen_results/test/test_01312_pred.png (deflated 0%)
#   adding: gen_results/test/test_00260_clean.png (deflated 0%)
#   adding: gen_results/test/test_01996_clean.png (deflated 0%)
#   adding: gen_results/test/test_01805_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01863_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00706_pred.png (deflated 0%)
#   adding: gen_results/test/test_00930_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00438_pred.png (deflated 0%)
#   adding: gen_results/test/test_00319_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01679_clean.png (stored 0%)
#   adding: gen_results/test/test_00169_clean.png (deflated 0%)
#   adding: gen_results/test/test_00606_clean.png (deflated 0%)
#   adding: gen_results/test/test_00695_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00296_clean.png (deflated 0%)
#   adding: gen_results/test/test_01289_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00274_clean.png (deflated 0%)
#   adding: gen_results/test/test_00991_clean.png (deflated 0%)
#   adding: gen_results/test/test_00920_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01801_clean.png (deflated 0%)
#   adding: gen_results/test/test_00973_pred.png (deflated 0%)
#   adding: gen_results/test/test_00094_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01814_pred.png (deflated 0%)
#   adding: gen_results/test/test_01686_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00616_clean.png (deflated 0%)
#   adding: gen_results/test/test_01447_clean.png (deflated 0%)
#   adding: gen_results/test/test_01218_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00046_pred.png (deflated 0%)
#   adding: gen_results/test/test_00948_pred.png (deflated 0%)
#   adding: gen_results/test/test_00201_pred.png (deflated 0%)
#   adding: gen_results/test/test_01298_pred.png (deflated 0%)
#   adding: gen_results/test/test_00808_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01252_pred.png (deflated 0%)
#   adding: gen_results/test/test_00192_clean.png (deflated 0%)
#   adding: gen_results/test/test_02022_clean.png (deflated 0%)
#   adding: gen_results/test/test_01637_pred.png (stored 0%)
#   adding: gen_results/test/test_01353_pred.png (deflated 0%)
#   adding: gen_results/test/test_00487_clean.png (deflated 0%)
#   adding: gen_results/test/test_00217_clean.png (deflated 0%)
#   adding: gen_results/test/test_01849_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01437_pred.png (deflated 0%)
#   adding: gen_results/test/test_01900_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00424_pred.png (deflated 0%)
#   adding: gen_results/test/test_01923_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01361_clean.png (deflated 0%)
#   adding: gen_results/test/test_01820_clean.png (deflated 0%)
#   adding: gen_results/test/test_00612_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00749_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01257_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01227_clean.png (deflated 0%)
#   adding: gen_results/test/test_00043_pred.png (deflated 0%)
#   adding: gen_results/test/test_00313_pred.png (deflated 0%)
#   adding: gen_results/test/test_00664_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00060_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01733_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01808_pred.png (deflated 0%)
#   adding: gen_results/test/test_00605_pred.png (deflated 0%)
#   adding: gen_results/test/test_01915_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00667_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01530_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01684_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01511_clean.png (deflated 0%)
#   adding: gen_results/test/test_01117_clean.png (stored 0%)
#   adding: gen_results/test/test_00936_clean.png (deflated 0%)
#   adding: gen_results/test/test_00746_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01073_clean.png (stored 0%)
#   adding: gen_results/test/test_01946_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01421_clean.png (deflated 0%)
#   adding: gen_results/test/test_00883_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01955_pred.png (deflated 0%)
#   adding: gen_results/test/test_02003_pred.png (deflated 0%)
#   adding: gen_results/test/test_02038_clean.png (deflated 0%)
#   adding: gen_results/test/test_01503_pred.png (deflated 0%)
#   adding: gen_results/test/test_01368_pred.png (deflated 0%)
#   adding: gen_results/test/test_01594_pred.png (deflated 0%)
#   adding: gen_results/test/test_01713_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01399_clean.png (deflated 0%)
#   adding: gen_results/test/test_01359_clean.png (deflated 0%)
#   adding: gen_results/test/test_00431_clean.png (stored 0%)
#   adding: gen_results/test/test_01510_pred.png (deflated 0%)
#   adding: gen_results/test/test_01712_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00211_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01718_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00630_clean.png (deflated 0%)
#   adding: gen_results/test/test_00990_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01987_clean.png (deflated 0%)
#   adding: gen_results/test/test_00077_clean.png (stored 0%)
#   adding: gen_results/test/test_00987_clean.png (deflated 0%)
#   adding: gen_results/test/test_01948_pred.png (deflated 0%)
#   adding: gen_results/test/test_01807_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00228_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01585_pred.png (deflated 0%)
#   adding: gen_results/test/test_00536_clean.png (deflated 0%)
#   adding: gen_results/test/test_01772_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00682_clean.png (deflated 0%)
#   adding: gen_results/test/test_00934_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01209_pred.png (deflated 0%)
#   adding: gen_results/test/test_00627_pred.png (deflated 0%)
#   adding: gen_results/test/test_00144_clean.png (deflated 0%)
#   adding: gen_results/test/test_00740_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00061_pred.png (deflated 0%)
#   adding: gen_results/test/test_02047_pred.png (deflated 0%)
#   adding: gen_results/test/test_00278_pred.png (deflated 0%)
#   adding: gen_results/test/test_01212_pred.png (deflated 0%)
#   adding: gen_results/test/test_00038_pred.png (deflated 0%)
#   adding: gen_results/test/test_01915_pred.png (deflated 0%)
#   adding: gen_results/test/test_01584_pred.png (deflated 0%)
#   adding: gen_results/test/test_00582_clean.png (deflated 0%)
#   adding: gen_results/test/test_00599_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01622_clean.png (stored 0%)
#   adding: gen_results/test/test_00797_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00316_clean.png (deflated 0%)
#   adding: gen_results/test/test_01638_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00479_clean.png (deflated 0%)
#   adding: gen_results/test/test_02044_clean.png (deflated 0%)
#   adding: gen_results/test/test_01764_clean.png (deflated 0%)
#   adding: gen_results/test/test_00041_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00843_pred.png (deflated 0%)
#   adding: gen_results/test/test_02046_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00866_clean.png (deflated 0%)
#   adding: gen_results/test/test_00526_pred.png (deflated 0%)
#   adding: gen_results/test/test_01848_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01116_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01736_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00002_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01444_pred.png (stored 0%)
#   adding: gen_results/test/test_01183_clean.png (deflated 0%)
#   adding: gen_results/test/test_01052_clean.png (deflated 0%)
#   adding: gen_results/test/test_00024_pred.png (deflated 0%)
#   adding: gen_results/test/test_00681_clean.png (deflated 0%)
#   adding: gen_results/test/test_01466_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01099_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00673_clean.png (deflated 0%)
#   adding: gen_results/test/test_01146_pred.png (deflated 0%)
#   adding: gen_results/test/test_01446_pred.png (deflated 0%)
#   adding: gen_results/test/test_01797_pred.png (deflated 0%)
#   adding: gen_results/test/test_00295_pred.png (deflated 0%)
#   adding: gen_results/test/test_00670_clean.png (stored 0%)
#   adding: gen_results/test/test_01575_clean.png (deflated 0%)
#   adding: gen_results/test/test_01919_clean.png (stored 0%)
#   adding: gen_results/test/test_00617_pred.png (deflated 0%)
#   adding: gen_results/test/test_00504_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01788_pred.png (deflated 0%)
#   adding: gen_results/test/test_01758_pred.png (deflated 0%)
#   adding: gen_results/test/test_00721_pred.png (deflated 0%)
#   adding: gen_results/test/test_00034_clean.png (deflated 0%)
#   adding: gen_results/test/test_01080_pred.png (deflated 0%)
#   adding: gen_results/test/test_02022_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01714_clean.png (deflated 0%)
#   adding: gen_results/test/test_00933_clean.png (deflated 0%)
#   adding: gen_results/test/test_01217_clean.png (stored 0%)
#   adding: gen_results/test/test_01726_clean.png (deflated 0%)
#   adding: gen_results/test/test_01442_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01603_pred.png (deflated 0%)
#   adding: gen_results/test/test_00578_clean.png (deflated 0%)
#   adding: gen_results/test/test_00348_clean.png (deflated 0%)
#   adding: gen_results/test/test_01076_clean.png (deflated 0%)
#   adding: gen_results/test/test_01208_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01507_clean.png (stored 0%)
#   adding: gen_results/test/test_00458_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01046_clean.png (stored 0%)
#   adding: gen_results/test/test_01327_pred.png (deflated 0%)
#   adding: gen_results/test/test_00161_clean.png (deflated 0%)
#   adding: gen_results/test/test_02025_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00472_pred.png (deflated 0%)
#   adding: gen_results/test/test_00657_pred.png (stored 0%)
#   adding: gen_results/test/test_01648_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01104_clean.png (deflated 0%)
#   adding: gen_results/test/test_00647_clean.png (deflated 0%)
#   adding: gen_results/test/test_00559_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00245_clean.png (stored 0%)
#   adding: gen_results/test/test_01427_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00361_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00794_pred.png (deflated 0%)
#   adding: gen_results/test/test_02044_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01294_pred.png (stored 0%)
#   adding: gen_results/test/test_01789_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00023_clean.png (stored 0%)
#   adding: gen_results/test/test_01843_pred.png (deflated 0%)
#   adding: gen_results/test/test_01656_pred.png (deflated 0%)
#   adding: gen_results/test/test_01923_pred.png (deflated 0%)
#   adding: gen_results/test/test_01569_pred.png (deflated 0%)
#   adding: gen_results/test/test_01641_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01822_pred.png (deflated 0%)
#   adding: gen_results/test/test_01693_pred.png (deflated 0%)
#   adding: gen_results/test/test_00728_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00648_pred.png (deflated 0%)
#   adding: gen_results/test/test_00073_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01387_clean.png (deflated 0%)
#   adding: gen_results/test/test_01494_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01100_pred.png (deflated 0%)
#   adding: gen_results/test/test_00848_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00309_clean.png (deflated 0%)
#   adding: gen_results/test/test_00543_clean.png (deflated 0%)
#   adding: gen_results/test/test_00149_clean.png (stored 0%)
#   adding: gen_results/test/test_01161_clean.png (deflated 0%)
#   adding: gen_results/test/test_01366_pred.png (deflated 0%)
#   adding: gen_results/test/test_01488_clean.png (deflated 0%)
#   adding: gen_results/test/test_01300_pred.png (deflated 0%)
#   adding: gen_results/test/test_01088_pred.png (deflated 0%)
#   adding: gen_results/test/test_00894_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00977_pred.png (deflated 0%)
#   adding: gen_results/test/test_00684_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00240_clean.png (deflated 0%)
#   adding: gen_results/test/test_01167_pred.png (deflated 0%)
#   adding: gen_results/test/test_00371_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00796_clean.png (deflated 0%)
#   adding: gen_results/test/test_01957_pred.png (deflated 0%)
#   adding: gen_results/test/test_01556_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01858_pred.png (deflated 0%)
#   adding: gen_results/test/test_00929_clean.png (deflated 0%)
#   adding: gen_results/test/test_00549_pred.png (deflated 0%)
#   adding: gen_results/test/test_01508_clean.png (deflated 0%)
#   adding: gen_results/test/test_01984_pred.png (deflated 0%)
#   adding: gen_results/test/test_00182_clean.png (stored 0%)
#   adding: gen_results/test/test_01358_clean.png (deflated 0%)
#   adding: gen_results/test/test_00334_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00810_pred.png (deflated 0%)
#   adding: gen_results/test/test_01797_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00446_pred.png (deflated 0%)
#   adding: gen_results/test/test_00665_pred.png (deflated 0%)
#   adding: gen_results/test/test_01809_clean.png (deflated 0%)
#   adding: gen_results/test/test_00672_pred.png (stored 0%)
#   adding: gen_results/test/test_00874_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01031_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00252_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01061_clean.png (deflated 0%)
#   adding: gen_results/test/test_01379_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00722_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01757_clean.png (deflated 0%)
#   adding: gen_results/test/test_01077_pred.png (deflated 0%)
#   adding: gen_results/test/test_00666_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00766_pred.png (deflated 0%)
#   adding: gen_results/test/test_00608_clean.png (deflated 0%)
#   adding: gen_results/test/test_00564_pred.png (deflated 0%)
#   adding: gen_results/test/test_00035_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00158_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00758_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00136_pred.png (deflated 0%)
#   adding: gen_results/test/test_00126_pred.png (deflated 0%)
#   adding: gen_results/test/test_01127_clean.png (stored 0%)
#   adding: gen_results/test/test_00569_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_02037_pred.png (deflated 0%)
#   adding: gen_results/test/test_01917_pred.png (deflated 0%)
#   adding: gen_results/test/test_00833_pred.png (deflated 0%)
#   adding: gen_results/test/test_00801_pred.png (deflated 0%)
#   adding: gen_results/test/test_01094_pred.png (deflated 0%)
#   adding: gen_results/test/test_01303_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00828_pred.png (deflated 0%)
#   adding: gen_results/test/test_00179_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00203_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00540_cloudy.png (stored 0%)
#   adding: gen_results/test/test_02028_pred.png (deflated 0%)
#   adding: gen_results/test/test_01794_pred.png (deflated 0%)
#   adding: gen_results/test/test_01797_clean.png (deflated 0%)
#   adding: gen_results/test/test_00093_clean.png (deflated 0%)
#   adding: gen_results/test/test_00088_pred.png (deflated 0%)
#   adding: gen_results/test/test_01328_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01926_clean.png (stored 0%)
#   adding: gen_results/test/test_00577_clean.png (stored 0%)
#   adding: gen_results/test/test_00736_pred.png (deflated 0%)
#   adding: gen_results/test/test_00563_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00882_pred.png (deflated 0%)
#   adding: gen_results/test/test_00207_clean.png (stored 0%)
#   adding: gen_results/test/test_00540_clean.png (deflated 0%)
#   adding: gen_results/test/test_01191_clean.png (deflated 0%)
#   adding: gen_results/test/test_01645_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00674_clean.png (stored 0%)
#   adding: gen_results/test/test_00238_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01551_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00555_pred.png (deflated 0%)
#   adding: gen_results/test/test_00233_clean.png (stored 0%)
#   adding: gen_results/test/test_00612_pred.png (deflated 0%)
#   adding: gen_results/test/test_00882_clean.png (deflated 0%)
#   adding: gen_results/test/test_00403_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01170_clean.png (deflated 0%)
#   adding: gen_results/test/test_00072_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00814_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00817_pred.png (deflated 0%)
#   adding: gen_results/test/test_01175_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01400_clean.png (deflated 0%)
#   adding: gen_results/test/test_00587_clean.png (deflated 0%)
#   adding: gen_results/test/test_01791_pred.png (deflated 0%)
#   adding: gen_results/test/test_00421_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01288_pred.png (deflated 0%)
#   adding: gen_results/test/test_01671_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01013_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01891_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01079_pred.png (deflated 0%)
#   adding: gen_results/test/test_00767_clean.png (deflated 0%)
#   adding: gen_results/test/test_00457_clean.png (deflated 0%)
#   adding: gen_results/test/test_01637_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00752_pred.png (deflated 0%)
#   adding: gen_results/test/test_01670_clean.png (deflated 0%)
#   adding: gen_results/test/test_01565_pred.png (deflated 0%)
#   adding: gen_results/test/test_01846_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01321_clean.png (stored 0%)
#   adding: gen_results/test/test_00909_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01213_pred.png (deflated 0%)
#   adding: gen_results/test/test_01840_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01556_pred.png (deflated 0%)
#   adding: gen_results/test/test_01011_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01791_clean.png (deflated 0%)
#   adding: gen_results/test/test_00408_pred.png (deflated 0%)
#   adding: gen_results/test/test_00726_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01733_clean.png (deflated 0%)
#   adding: gen_results/test/test_00305_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01254_pred.png (deflated 0%)
#   adding: gen_results/test/test_01272_clean.png (stored 0%)
#   adding: gen_results/test/test_00760_clean.png (stored 0%)
#   adding: gen_results/test/test_01739_clean.png (stored 0%)
#   adding: gen_results/test/test_01630_pred.png (deflated 0%)
#   adding: gen_results/test/test_01951_pred.png (deflated 0%)
#   adding: gen_results/test/test_00847_pred.png (deflated 0%)
#   adding: gen_results/test/test_00786_pred.png (deflated 0%)
#   adding: gen_results/test/test_01930_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00609_clean.png (deflated 0%)
#   adding: gen_results/test/test_01341_clean.png (deflated 0%)
#   adding: gen_results/test/test_01892_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00465_clean.png (stored 0%)
#   adding: gen_results/test/test_00988_pred.png (deflated 0%)
#   adding: gen_results/test/test_01932_clean.png (stored 0%)
#   adding: gen_results/test/test_01224_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00231_clean.png (deflated 0%)
#   adding: gen_results/test/test_01075_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00580_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01783_clean.png (stored 0%)
#   adding: gen_results/test/test_01492_clean.png (deflated 0%)
#   adding: gen_results/test/test_00716_clean.png (deflated 0%)
#   adding: gen_results/test/test_00804_clean.png (deflated 0%)
#   adding: gen_results/test/test_01753_pred.png (stored 0%)
#   adding: gen_results/test/test_00409_pred.png (deflated 0%)
#   adding: gen_results/test/test_01158_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00783_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01823_pred.png (deflated 0%)
#   adding: gen_results/test/test_00475_cloudy.png (stored 0%)
#   adding: gen_results/test/test_02036_clean.png (stored 0%)
#   adding: gen_results/test/test_01129_pred.png (deflated 0%)
#   adding: gen_results/test/test_01160_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00993_clean.png (deflated 0%)
#   adding: gen_results/test/test_01754_pred.png (deflated 0%)
#   adding: gen_results/test/test_00123_clean.png (deflated 0%)
#   adding: gen_results/test/test_01907_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00037_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00808_pred.png (deflated 0%)
#   adding: gen_results/test/test_01821_pred.png (deflated 0%)
#   adding: gen_results/test/test_00625_pred.png (deflated 0%)
#   adding: gen_results/test/test_00617_clean.png (deflated 0%)
#   adding: gen_results/test/test_00515_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01035_pred.png (deflated 0%)
#   adding: gen_results/test/test_01278_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00977_clean.png (deflated 0%)
#   adding: gen_results/test/test_01061_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00392_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01264_pred.png (deflated 0%)
#   adding: gen_results/test/test_00032_clean.png (deflated 0%)
#   adding: gen_results/test/test_00165_pred.png (deflated 0%)
#   adding: gen_results/test/test_01925_pred.png (deflated 0%)
#   adding: gen_results/test/test_00430_clean.png (deflated 0%)
#   adding: gen_results/test/test_01451_clean.png (deflated 0%)
#   adding: gen_results/test/test_00220_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01762_clean.png (deflated 0%)
#   adding: gen_results/test/test_00684_pred.png (deflated 0%)
#   adding: gen_results/test/test_00825_pred.png (deflated 0%)
#   adding: gen_results/test/test_01391_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00918_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01662_pred.png (stored 0%)
#   adding: gen_results/test/test_00036_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00616_pred.png (deflated 0%)
#   adding: gen_results/test/test_01306_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01228_clean.png (deflated 0%)
#   adding: gen_results/test/test_01597_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00113_clean.png (deflated 0%)
#   adding: gen_results/test/test_01192_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01974_pred.png (deflated 0%)
#   adding: gen_results/test/test_01275_pred.png (deflated 0%)
#   adding: gen_results/test/test_01336_pred.png (deflated 0%)
#   adding: gen_results/test/test_01582_clean.png (stored 0%)
#   adding: gen_results/test/test_00974_clean.png (deflated 0%)
#   adding: gen_results/test/test_00214_pred.png (deflated 0%)
#   adding: gen_results/test/test_00339_pred.png (deflated 0%)
#   adding: gen_results/test/test_00362_pred.png (deflated 0%)
#   adding: gen_results/test/test_01181_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01960_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01243_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01668_pred.png (deflated 0%)
#   adding: gen_results/test/test_01843_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01552_pred.png (stored 0%)
#   adding: gen_results/test/test_00498_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01680_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00107_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01110_pred.png (deflated 0%)
#   adding: gen_results/test/test_00831_clean.png (stored 0%)
#   adding: gen_results/test/test_01572_clean.png (deflated 0%)
#   adding: gen_results/test/test_01018_clean.png (deflated 0%)
#   adding: gen_results/test/test_00002_clean.png (deflated 0%)
#   adding: gen_results/test/test_00574_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00933_pred.png (deflated 0%)
#   adding: gen_results/test/test_01678_clean.png (stored 0%)
#   adding: gen_results/test/test_01855_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00913_clean.png (stored 0%)
#   adding: gen_results/test/test_01299_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00388_pred.png (deflated 0%)
#   adding: gen_results/test/test_00369_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00632_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01629_pred.png (deflated 0%)
#   adding: gen_results/test/test_00737_clean.png (deflated 0%)
#   adding: gen_results/test/test_00302_pred.png (deflated 0%)
#   adding: gen_results/test/test_01852_pred.png (deflated 0%)
#   adding: gen_results/test/test_00778_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00174_pred.png (deflated 0%)
#   adding: gen_results/test/test_00506_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00223_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01969_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00678_pred.png (deflated 0%)
#   adding: gen_results/test/test_00190_clean.png (deflated 0%)
#   adding: gen_results/test/test_00545_pred.png (deflated 0%)
#   adding: gen_results/test/test_01828_clean.png (deflated 0%)
#   adding: gen_results/test/test_00014_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00098_pred.png (deflated 0%)
#   adding: gen_results/test/test_01453_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00882_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01945_pred.png (deflated 0%)
#   adding: gen_results/test/test_00161_pred.png (deflated 0%)
#   adding: gen_results/test/test_01084_clean.png (deflated 0%)
#   adding: gen_results/test/test_01544_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01694_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00813_clean.png (stored 0%)
#   adding: gen_results/test/test_01096_pred.png (deflated 0%)
#   adding: gen_results/test/test_01343_pred.png (deflated 0%)
#   adding: gen_results/test/test_00622_pred.png (deflated 0%)
#   adding: gen_results/test/test_01311_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01413_clean.png (stored 0%)
#   adding: gen_results/test/test_00494_pred.png (deflated 0%)
#   adding: gen_results/test/test_01642_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00444_pred.png (deflated 0%)
#   adding: gen_results/test/test_00157_pred.png (deflated 0%)
#   adding: gen_results/test/test_01839_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01462_pred.png (deflated 0%)
#   adding: gen_results/test/test_00333_clean.png (deflated 0%)
#   adding: gen_results/test/test_00362_clean.png (deflated 0%)
#   adding: gen_results/test/test_00132_clean.png (deflated 0%)
#   adding: gen_results/test/test_01645_clean.png (deflated 0%)
#   adding: gen_results/test/test_01892_clean.png (deflated 0%)
#   adding: gen_results/test/test_00850_pred.png (deflated 0%)
#   adding: gen_results/test/test_00828_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01731_clean.png (deflated 0%)
#   adding: gen_results/test/test_01722_clean.png (deflated 0%)
#   adding: gen_results/test/test_00465_pred.png (stored 0%)
#   adding: gen_results/test/test_01723_clean.png (deflated 0%)
#   adding: gen_results/test/test_01756_pred.png (deflated 0%)
#   adding: gen_results/test/test_00720_clean.png (stored 0%)
#   adding: gen_results/test/test_00958_clean.png (deflated 0%)
#   adding: gen_results/test/test_01798_pred.png (deflated 0%)
#   adding: gen_results/test/test_01688_clean.png (deflated 0%)
#   adding: gen_results/test/test_02018_pred.png (deflated 0%)
#   adding: gen_results/test/test_01853_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01751_clean.png (deflated 0%)
#   adding: gen_results/test/test_01759_pred.png (stored 0%)
#   adding: gen_results/test/test_01773_clean.png (stored 0%)
#   adding: gen_results/test/test_00688_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00031_clean.png (deflated 0%)
#   adding: gen_results/test/test_01203_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00033_pred.png (deflated 0%)
#   adding: gen_results/test/test_01004_clean.png (deflated 0%)
#   adding: gen_results/test/test_01217_pred.png (stored 0%)
#   adding: gen_results/test/test_01509_pred.png (deflated 0%)
#   adding: gen_results/test/test_01057_pred.png (deflated 0%)
#   adding: gen_results/test/test_01095_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00702_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00306_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00757_pred.png (deflated 0%)
#   adding: gen_results/test/test_01079_clean.png (deflated 0%)
#   adding: gen_results/test/test_00693_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00530_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01813_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01033_clean.png (stored 0%)
#   adding: gen_results/test/test_01077_clean.png (deflated 0%)
#   adding: gen_results/test/test_01540_pred.png (deflated 0%)
#   adding: gen_results/test/test_01616_pred.png (deflated 0%)
#   adding: gen_results/test/test_01906_pred.png (deflated 0%)
#   adding: gen_results/test/test_01842_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01716_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01845_clean.png (deflated 0%)
#   adding: gen_results/test/test_01898_pred.png (deflated 0%)
#   adding: gen_results/test/test_01911_clean.png (deflated 0%)
#   adding: gen_results/test/test_01062_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00180_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00531_pred.png (deflated 0%)
#   adding: gen_results/test/test_00528_pred.png (deflated 0%)
#   adding: gen_results/test/test_00358_pred.png (deflated 0%)
#   adding: gen_results/test/test_01522_pred.png (deflated 0%)
#   adding: gen_results/test/test_01342_clean.png (deflated 0%)
#   adding: gen_results/test/test_00349_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01082_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00537_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00047_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00905_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01498_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00156_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00200_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01446_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00376_pred.png (deflated 0%)
#   adding: gen_results/test/test_01637_clean.png (stored 0%)
#   adding: gen_results/test/test_00734_pred.png (deflated 0%)
#   adding: gen_results/test/test_00595_pred.png (deflated 0%)
#   adding: gen_results/test/test_00350_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01364_pred.png (deflated 0%)
#   adding: gen_results/test/test_00087_clean.png (deflated 0%)
#   adding: gen_results/test/test_00078_pred.png (deflated 0%)
#   adding: gen_results/test/test_00310_pred.png (deflated 0%)
#   adding: gen_results/test/test_01725_pred.png (deflated 0%)
#   adding: gen_results/test/test_01525_clean.png (deflated 0%)
#   adding: gen_results/test/test_01292_clean.png (deflated 0%)
#   adding: gen_results/test/test_01287_clean.png (stored 0%)
#   adding: gen_results/test/test_00840_clean.png (stored 0%)
#   adding: gen_results/test/test_01653_pred.png (deflated 0%)
#   adding: gen_results/test/test_00202_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01625_pred.png (deflated 0%)
#   adding: gen_results/test/test_01739_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01299_clean.png (stored 0%)
#   adding: gen_results/test/test_00780_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00226_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00329_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00364_pred.png (stored 0%)
#   adding: gen_results/test/test_01475_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00142_pred.png (deflated 0%)
#   adding: gen_results/test/test_01746_clean.png (deflated 0%)
#   adding: gen_results/test/test_00335_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01820_pred.png (deflated 0%)
#   adding: gen_results/test/test_01266_pred.png (deflated 0%)
#   adding: gen_results/test/test_01297_pred.png (deflated 0%)
#   adding: gen_results/test/test_00989_pred.png (deflated 0%)
#   adding: gen_results/test/test_01928_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01343_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01928_clean.png (deflated 0%)
#   adding: gen_results/test/test_00401_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01850_clean.png (deflated 0%)
#   adding: gen_results/test/test_00954_clean.png (deflated 0%)
#   adding: gen_results/test/test_01204_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00405_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01541_clean.png (deflated 0%)
#   adding: gen_results/test/test_01703_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00436_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00335_clean.png (deflated 0%)
#   adding: gen_results/test/test_01760_clean.png (deflated 0%)
#   adding: gen_results/test/test_00634_clean.png (stored 0%)
#   adding: gen_results/test/test_00847_clean.png (deflated 0%)
#   adding: gen_results/test/test_00181_clean.png (stored 0%)
#   adding: gen_results/test/test_00354_pred.png (deflated 0%)
#   adding: gen_results/test/test_00672_clean.png (stored 0%)
#   adding: gen_results/test/test_00862_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00239_clean.png (deflated 0%)
#   adding: gen_results/test/test_01163_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00644_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00338_pred.png (deflated 0%)
#   adding: gen_results/test/test_01633_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01139_clean.png (deflated 0%)
#   adding: gen_results/test/test_01255_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01912_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01459_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01617_clean.png (deflated 0%)
#   adding: gen_results/test/test_00992_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01079_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01774_pred.png (deflated 0%)
#   adding: gen_results/test/test_00207_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01357_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00947_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01179_clean.png (deflated 0%)
#   adding: gen_results/test/test_00638_clean.png (deflated 0%)
#   adding: gen_results/test/test_00214_clean.png (deflated 0%)
#   adding: gen_results/test/test_00809_pred.png (deflated 0%)
#   adding: gen_results/test/test_01622_pred.png (deflated 0%)
#   adding: gen_results/test/test_00996_pred.png (deflated 0%)
#   adding: gen_results/test/test_01042_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01721_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01253_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01939_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00462_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00132_pred.png (deflated 0%)
#   adding: gen_results/test/test_01682_pred.png (deflated 0%)
#   adding: gen_results/test/test_01981_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01726_pred.png (deflated 0%)
#   adding: gen_results/test/test_01631_pred.png (deflated 0%)
#   adding: gen_results/test/test_01004_pred.png (deflated 0%)
#   adding: gen_results/test/test_00790_pred.png (deflated 0%)
#   adding: gen_results/test/test_01433_pred.png (deflated 0%)
#   adding: gen_results/test/test_00041_pred.png (deflated 0%)
#   adding: gen_results/test/test_00659_pred.png (deflated 0%)
#   adding: gen_results/test/test_00733_pred.png (deflated 0%)
#   adding: gen_results/test/test_01927_pred.png (deflated 0%)
#   adding: gen_results/test/test_00450_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00392_pred.png (deflated 0%)
#   adding: gen_results/test/test_00868_pred.png (deflated 0%)
#   adding: gen_results/test/test_00303_clean.png (deflated 0%)
#   adding: gen_results/test/test_01165_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01300_clean.png (deflated 0%)
#   adding: gen_results/test/test_01353_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00593_pred.png (stored 0%)
#   adding: gen_results/test/test_01080_clean.png (deflated 0%)
#   adding: gen_results/test/test_01406_clean.png (deflated 0%)
#   adding: gen_results/test/test_00538_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01490_pred.png (deflated 0%)
#   adding: gen_results/test/test_00980_pred.png (deflated 0%)
#   adding: gen_results/test/test_00639_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01963_clean.png (deflated 0%)
#   adding: gen_results/test/test_01826_pred.png (deflated 0%)
#   adding: gen_results/test/test_01784_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00553_pred.png (deflated 0%)
#   adding: gen_results/test/test_01785_pred.png (deflated 0%)
#   adding: gen_results/test/test_01949_clean.png (deflated 0%)
#   adding: gen_results/test/test_01872_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00089_clean.png (deflated 0%)
#   adding: gen_results/test/test_00787_clean.png (deflated 0%)
#   adding: gen_results/test/test_00355_clean.png (stored 0%)
#   adding: gen_results/test/test_00497_pred.png (deflated 0%)
#   adding: gen_results/test/test_00959_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00386_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00160_pred.png (deflated 0%)
#   adding: gen_results/test/test_00181_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00633_clean.png (deflated 0%)
#   adding: gen_results/test/test_01691_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00434_pred.png (deflated 0%)
#   adding: gen_results/test/test_01402_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00896_pred.png (deflated 0%)
#   adding: gen_results/test/test_01172_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00385_clean.png (deflated 0%)
#   adding: gen_results/test/test_01293_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00331_clean.png (deflated 0%)
#   adding: gen_results/test/test_00439_clean.png (deflated 0%)
#   adding: gen_results/test/test_00373_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01010_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00234_clean.png (deflated 0%)
#   adding: gen_results/test/test_00653_pred.png (deflated 0%)
#   adding: gen_results/test/test_00121_pred.png (deflated 0%)
#   adding: gen_results/test/test_01676_clean.png (stored 0%)
#   adding: gen_results/test/test_01394_pred.png (deflated 0%)
#   adding: gen_results/test/test_01155_clean.png (deflated 0%)
#   adding: gen_results/test/test_01973_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00077_pred.png (stored 0%)
#   adding: gen_results/test/test_01784_pred.png (deflated 0%)
#   adding: gen_results/test/test_00360_pred.png (deflated 0%)
#   adding: gen_results/test/test_01085_clean.png (deflated 0%)
#   adding: gen_results/test/test_00857_clean.png (stored 0%)
#   adding: gen_results/test/test_01634_clean.png (stored 0%)
#   adding: gen_results/test/test_01690_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00597_clean.png (deflated 0%)
#   adding: gen_results/test/test_01824_clean.png (deflated 0%)
#   adding: gen_results/test/test_00591_clean.png (deflated 0%)
#   adding: gen_results/test/test_00250_pred.png (deflated 0%)
#   adding: gen_results/test/test_00066_pred.png (deflated 0%)
#   adding: gen_results/test/test_02032_pred.png (deflated 0%)
#   adding: gen_results/test/test_01404_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01311_pred.png (deflated 0%)
#   adding: gen_results/test/test_00621_pred.png (deflated 0%)
#   adding: gen_results/test/test_01939_clean.png (deflated 0%)
#   adding: gen_results/test/test_02023_clean.png (stored 0%)
#   adding: gen_results/test/test_00290_pred.png (deflated 0%)
#   adding: gen_results/test/test_00290_clean.png (deflated 0%)
#   adding: gen_results/test/test_00588_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01242_pred.png (deflated 0%)
#   adding: gen_results/test/test_00200_clean.png (deflated 0%)
#   adding: gen_results/test/test_01538_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01542_clean.png (deflated 0%)
#   adding: gen_results/test/test_00725_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01790_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00440_pred.png (deflated 0%)
#   adding: gen_results/test/test_00101_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01365_clean.png (stored 0%)
#   adding: gen_results/test/test_01762_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01985_clean.png (deflated 0%)
#   adding: gen_results/test/test_01848_clean.png (deflated 0%)
#   adding: gen_results/test/test_01783_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01068_clean.png (deflated 0%)
#   adding: gen_results/test/test_00194_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00850_clean.png (stored 0%)
#   adding: gen_results/test/test_00709_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01975_pred.png (deflated 0%)
#   adding: gen_results/test/test_01151_clean.png (deflated 0%)
#   adding: gen_results/test/test_01301_clean.png (deflated 0%)
#   adding: gen_results/test/test_00342_clean.png (deflated 0%)
#   adding: gen_results/test/test_01100_clean.png (deflated 0%)
#   adding: gen_results/test/test_02008_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00189_pred.png (deflated 0%)
#   adding: gen_results/test/test_01420_pred.png (deflated 0%)
#   adding: gen_results/test/test_00384_clean.png (deflated 0%)
#   adding: gen_results/test/test_01658_pred.png (deflated 0%)
#   adding: gen_results/test/test_00211_clean.png (stored 0%)
#   adding: gen_results/test/test_01345_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01918_pred.png (deflated 0%)
#   adding: gen_results/test/test_00455_clean.png (deflated 0%)
#   adding: gen_results/test/test_01938_clean.png (stored 0%)
#   adding: gen_results/test/test_00486_clean.png (stored 0%)
#   adding: gen_results/test/test_00687_clean.png (stored 0%)
#   adding: gen_results/test/test_00530_clean.png (deflated 0%)
#   adding: gen_results/test/test_00789_clean.png (stored 0%)
#   adding: gen_results/test/test_01480_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00723_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01658_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01517_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01620_clean.png (deflated 0%)
#   adding: gen_results/test/test_02009_clean.png (deflated 0%)
#   adding: gen_results/test/test_00303_pred.png (deflated 0%)
#   adding: gen_results/test/test_00685_clean.png (deflated 0%)
#   adding: gen_results/test/test_00135_pred.png (deflated 0%)
#   adding: gen_results/test/test_00175_clean.png (deflated 0%)
#   adding: gen_results/test/test_00353_pred.png (deflated 0%)
#   adding: gen_results/test/test_01041_cloudy.png (deflated 0%)
# ...
#   adding: gen_results/test/test_01667_pred.png (deflated 0%)
#   adding: gen_results/test/test_00943_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01754_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00015_pred.png (deflated 0%)
#   adding: gen_results/test/test_01328_clean.png (deflated 0%)
#   adding: gen_results/test/test_01742_clean.png (deflated 0%)
#   adding: gen_results/test/test_01767_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00795_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00097_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01407_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01640_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01158_clean.png (deflated 0%)
#   adding: gen_results/test/test_00110_pred.png (stored 0%)
#   adding: gen_results/test/test_00035_clean.png (deflated 0%)
#   adding: gen_results/test/test_00051_clean.png (deflated 0%)
#   adding: gen_results/test/test_01883_clean.png (deflated 0%)
#   adding: gen_results/test/test_01160_pred.png (deflated 0%)
#   adding: gen_results/test/test_01867_clean.png (deflated 0%)
#   adding: gen_results/test/test_00550_pred.png (deflated 0%)
#   adding: gen_results/test/test_01705_clean.png (stored 0%)
#   adding: gen_results/test/test_00395_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01053_clean.png (deflated 0%)
#   adding: gen_results/test/test_00583_pred.png (deflated 0%)
#   adding: gen_results/test/test_00658_pred.png (deflated 0%)
#   adding: gen_results/test/test_01881_pred.png (deflated 0%)
#   adding: gen_results/test/test_01837_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00228_pred.png (deflated 0%)
#   adding: gen_results/test/test_00656_clean.png (stored 0%)
#   adding: gen_results/test/test_00880_pred.png (deflated 0%)
#   adding: gen_results/test/test_01738_clean.png (deflated 0%)
#   adding: gen_results/test/test_00072_pred.png (deflated 0%)
#   adding: gen_results/test/test_00855_pred.png (deflated 0%)
#   adding: gen_results/test/test_01462_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01934_clean.png (deflated 0%)
#   adding: gen_results/test/test_01342_pred.png (deflated 0%)
#   adding: gen_results/test/test_00626_pred.png (deflated 0%)
#   adding: gen_results/test/test_01064_clean.png (deflated 0%)
#   adding: gen_results/test/test_02007_clean.png (deflated 0%)
#   adding: gen_results/test/test_01527_pred.png (deflated 0%)
#   adding: gen_results/test/test_00443_pred.png (deflated 0%)
#   adding: gen_results/test/test_02024_clean.png (stored 0%)
#   adding: gen_results/test/test_01772_pred.png (deflated 0%)
#   adding: gen_results/test/test_01727_pred.png (deflated 0%)
#   adding: gen_results/test/test_01087_clean.png (deflated 0%)
#   adding: gen_results/test/test_01178_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00330_pred.png (deflated 0%)
#   adding: gen_results/test/test_01633_pred.png (stored 0%)
#   adding: gen_results/test/test_00012_clean.png (deflated 0%)
#   adding: gen_results/test/test_01936_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01798_clean.png (deflated 0%)
#   adding: gen_results/test/test_01046_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00725_clean.png (deflated 0%)
#   adding: gen_results/test/test_00842_pred.png (deflated 0%)
#   adding: gen_results/test/test_00567_pred.png (deflated 0%)
#   adding: gen_results/test/test_00435_clean.png (deflated 0%)
#   adding: gen_results/test/test_00740_clean.png (stored 0%)
#   adding: gen_results/test/test_01012_clean.png (deflated 0%)
#   adding: gen_results/test/test_01470_pred.png (deflated 0%)
#   adding: gen_results/test/test_01589_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00084_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00562_clean.png (deflated 0%)
#   adding: gen_results/test/test_01536_clean.png (deflated 0%)
#   adding: gen_results/test/test_00739_pred.png (deflated 0%)
#   adding: gen_results/test/test_01139_pred.png (deflated 0%)
#   adding: gen_results/test/test_01717_pred.png (deflated 0%)
#   adding: gen_results/test/test_00283_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01150_pred.png (deflated 0%)
#   adding: gen_results/test/test_01752_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01720_clean.png (deflated 0%)
#   adding: gen_results/test/test_01434_pred.png (deflated 0%)
#   adding: gen_results/test/test_00001_pred.png (deflated 0%)
#   adding: gen_results/test/test_00287_clean.png (deflated 0%)
#   adding: gen_results/test/test_01074_clean.png (stored 0%)
#   adding: gen_results/test/test_00455_pred.png (deflated 0%)
#   adding: gen_results/test/test_00104_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00767_pred.png (deflated 0%)
#   adding: gen_results/test/test_00745_clean.png (deflated 0%)
#   adding: gen_results/test/test_00652_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01566_pred.png (deflated 0%)
#   adding: gen_results/test/test_01832_pred.png (deflated 0%)
#   adding: gen_results/test/test_01711_pred.png (deflated 0%)
#   adding: gen_results/test/test_01638_clean.png (stored 0%)
#   adding: gen_results/test/test_00701_clean.png (deflated 0%)
#   adding: gen_results/test/test_00813_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00221_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01884_pred.png (deflated 0%)
#   adding: gen_results/test/test_01625_clean.png (deflated 0%)
#   adding: gen_results/test/test_00992_clean.png (deflated 0%)
#   adding: gen_results/test/test_01676_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01531_pred.png (stored 0%)
#   adding: gen_results/test/test_00709_pred.png (deflated 0%)
#   adding: gen_results/test/test_00259_clean.png (deflated 0%)
#   adding: gen_results/test/test_01267_clean.png (deflated 0%)
#   adding: gen_results/test/test_00218_pred.png (deflated 0%)
#   adding: gen_results/test/test_00517_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00168_pred.png (deflated 0%)
#   adding: gen_results/test/test_01193_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01603_clean.png (deflated 0%)
#   adding: gen_results/test/test_01928_pred.png (deflated 0%)
#   adding: gen_results/test/test_00535_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01653_clean.png (deflated 0%)
#   adding: gen_results/test/test_01051_pred.png (deflated 0%)
#   adding: gen_results/test/test_01838_clean.png (deflated 0%)
#   adding: gen_results/test/test_00219_clean.png (stored 0%)
#   adding: gen_results/test/test_00751_pred.png (deflated 0%)
#   adding: gen_results/test/test_00374_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01093_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00458_pred.png (deflated 0%)
#   adding: gen_results/test/test_01114_clean.png (deflated 0%)
#   adding: gen_results/test/test_01844_clean.png (deflated 0%)
#   adding: gen_results/test/test_00888_clean.png (deflated 0%)
#   adding: gen_results/test/test_01310_pred.png (deflated 0%)
#   adding: gen_results/test/test_01990_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00739_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00513_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01527_clean.png (stored 0%)
#   adding: gen_results/test/test_01232_clean.png (deflated 0%)
#   adding: gen_results/test/test_01371_pred.png (deflated 0%)
#   adding: gen_results/test/test_01967_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01249_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00234_pred.png (deflated 0%)
#   adding: gen_results/test/test_01441_clean.png (deflated 0%)
#   adding: gen_results/test/test_00223_pred.png (deflated 0%)
#   adding: gen_results/test/test_00379_clean.png (deflated 0%)
#   adding: gen_results/test/test_00900_pred.png (deflated 0%)
#   adding: gen_results/test/test_01927_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00679_pred.png (deflated 0%)
#   adding: gen_results/test/test_01484_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00128_clean.png (stored 0%)
#   adding: gen_results/test/test_01508_pred.png (deflated 0%)
#   adding: gen_results/test/test_01348_clean.png (stored 0%)
#   adding: gen_results/test/test_00646_clean.png (deflated 0%)
#   adding: gen_results/test/test_00011_pred.png (deflated 0%)
#   adding: gen_results/test/test_00038_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01337_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00288_pred.png (deflated 0%)
#   adding: gen_results/test/test_01545_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00948_clean.png (deflated 0%)
#   adding: gen_results/test/test_01955_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00370_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00886_pred.png (deflated 0%)
#   adding: gen_results/test/test_02002_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00332_clean.png (deflated 0%)
#   adding: gen_results/test/test_01734_pred.png (deflated 0%)
#   adding: gen_results/test/test_00537_pred.png (deflated 0%)
#   adding: gen_results/test/test_01538_clean.png (stored 0%)
#   adding: gen_results/test/test_01450_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00254_clean.png (deflated 0%)
#   adding: gen_results/test/test_01119_clean.png (deflated 0%)
#   adding: gen_results/test/test_01468_clean.png (deflated 0%)
#   adding: gen_results/test/test_01700_pred.png (deflated 0%)
#   adding: gen_results/test/test_01932_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01223_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01415_clean.png (deflated 0%)
#   adding: gen_results/test/test_01605_clean.png (deflated 0%)
#   adding: gen_results/test/test_00113_pred.png (deflated 0%)
#   adding: gen_results/test/test_01557_clean.png (deflated 0%)
#   adding: gen_results/test/test_00428_pred.png (deflated 0%)
#   adding: gen_results/test/test_01263_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00273_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01174_pred.png (stored 0%)
#   adding: gen_results/test/test_00747_clean.png (stored 0%)
#   adding: gen_results/test/test_01541_pred.png (deflated 0%)
#   adding: gen_results/test/test_01149_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01355_clean.png (deflated 0%)
#   adding: gen_results/test/test_01017_pred.png (deflated 0%)
#   adding: gen_results/test/test_00949_pred.png (deflated 0%)
#   adding: gen_results/test/test_00586_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00714_pred.png (deflated 0%)
#   adding: gen_results/test/test_00594_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01532_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00967_pred.png (deflated 0%)
#   adding: gen_results/test/test_00482_pred.png (deflated 0%)
#   adding: gen_results/test/test_00050_clean.png (deflated 0%)
#   adding: gen_results/test/test_01882_clean.png (deflated 0%)
#   adding: gen_results/test/test_00587_pred.png (deflated 0%)
#   adding: gen_results/test/test_01866_clean.png (deflated 0%)
#   adding: gen_results/test/test_01862_pred.png (deflated 0%)
#   adding: gen_results/test/test_00429_pred.png (deflated 0%)
#   adding: gen_results/test/test_00451_pred.png (deflated 0%)
#   adding: gen_results/test/test_01430_pred.png (deflated 0%)
#   adding: gen_results/test/test_00154_pred.png (deflated 0%)
#   adding: gen_results/test/test_01383_pred.png (deflated 0%)
#   adding: gen_results/test/test_00953_clean.png (deflated 0%)
#   adding: gen_results/test/test_00061_clean.png (deflated 0%)
#   adding: gen_results/test/test_00586_pred.png (deflated 0%)
#   adding: gen_results/test/test_02008_pred.png (deflated 0%)
#   adding: gen_results/test/test_01314_pred.png (deflated 0%)
#   adding: gen_results/test/test_00130_clean.png (deflated 0%)
#   adding: gen_results/test/test_01778_clean.png (deflated 0%)
#   adding: gen_results/test/test_01732_pred.png (deflated 0%)
#   adding: gen_results/test/test_01786_pred.png (deflated 0%)
#   adding: gen_results/test/test_01567_pred.png (deflated 0%)
#   adding: gen_results/test/test_00516_pred.png (deflated 0%)
#   adding: gen_results/test/test_01086_clean.png (deflated 0%)
#   adding: gen_results/test/test_00015_clean.png (stored 0%)
#   adding: gen_results/test/test_00456_clean.png (stored 0%)
#   adding: gen_results/test/test_00424_clean.png (stored 0%)
#   adding: gen_results/test/test_01884_clean.png (deflated 0%)
#   adding: gen_results/test/test_01065_pred.png (deflated 0%)
#   adding: gen_results/test/test_01094_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00004_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00812_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01578_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01042_pred.png (deflated 0%)
#   adding: gen_results/test/test_00333_pred.png (deflated 0%)
#   adding: gen_results/test/test_00209_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00878_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00926_clean.png (stored 0%)
#   adding: gen_results/test/test_01625_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01169_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00154_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00878_clean.png (stored 0%)
#   adding: gen_results/test/test_01595_pred.png (deflated 0%)
#   adding: gen_results/test/test_01845_pred.png (deflated 0%)
#   adding: gen_results/test/test_00638_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01345_clean.png (stored 0%)
#   adding: gen_results/test/test_01605_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01702_pred.png (stored 0%)
#   adding: gen_results/test/test_00525_clean.png (deflated 0%)
#   adding: gen_results/test/test_01941_clean.png (deflated 0%)
#   adding: gen_results/test/test_00011_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00279_clean.png (deflated 0%)
#   adding: gen_results/test/test_00673_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01334_pred.png (deflated 0%)
#   adding: gen_results/test/test_00248_pred.png (deflated 0%)
#   adding: gen_results/test/test_01451_pred.png (deflated 0%)
#   adding: gen_results/test/test_00336_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01431_clean.png (stored 0%)
#   adding: gen_results/test/test_00531_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01564_clean.png (deflated 0%)
#   adding: gen_results/test/test_00961_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01321_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01384_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00856_clean.png (deflated 0%)
#   adding: gen_results/test/test_00568_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00492_clean.png (stored 0%)
#   adding: gen_results/test/test_00576_pred.png (deflated 0%)
#   adding: gen_results/test/test_00354_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00366_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01420_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01268_clean.png (deflated 0%)
#   adding: gen_results/test/test_01599_pred.png (deflated 0%)
#   adding: gen_results/test/test_00957_pred.png (deflated 0%)
#   adding: gen_results/test/test_01376_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00888_pred.png (deflated 0%)
#   adding: gen_results/test/test_00651_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00460_pred.png (deflated 0%)
#   adding: gen_results/test/test_00541_clean.png (deflated 0%)
#   adding: gen_results/test/test_02003_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_01963_cloudy.png (deflated 0%)
#   adding: gen_results/test/test_00843_clean.png (deflated 0%)
#   adding: gen_results/test/test_00349_clean.png (deflated 0%)
#   adding: gen_results/test/test_00340_pred.png (deflated 0%)
#   adding: gen_results/test/test_00466_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01161_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01541_cloudy.png (stored 0%)
#   adding: gen_results/test/test_00272_cloudy.png (stored 0%)
#   adding: gen_results/test/test_01730_pred.png (deflated 0%)
#   adding: gen_results/test/test_00448_cloudy.png (deflated 0%)

# %%
from google.colab import files
files.download("gen_results.zip")
