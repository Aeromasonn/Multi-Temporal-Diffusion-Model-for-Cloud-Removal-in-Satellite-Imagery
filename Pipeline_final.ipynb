# %%
import torch
import importlib
import wrapped.Dataloader as Dataloader
importlib.reload(Dataloader)

from wrapped.Dataloader import prep_data_local

# %%
path = "./Sen2_MTC_Mini"
patch_size = 128
stride = 128
batch_size = 16
train_ratio = .7
val_ratio = .15

train_loader, val_loader, test_loader = prep_data_local(path=path, 
                                                        patch_size=patch_size, 
                                                        stride=stride,
                                                        batch_size=batch_size,
                                                        train_ratio=train_ratio,
                                                        val_ratio=val_ratio)
#expect ~40s run on full Sen2_MTC data
# Out:
# [Sen2-MTC Data loaded] Total samples: 4200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 8
#       5 train_ratio = .7
#       6 val_ratio = .15
# ----> 8 train_loader, val_loader, test_loader = prep_data_local(path=path,
#       9                                                         patch_size=patch_size,
#      10                                                         stride=stride,
#      11                                                         batch_size=batch_size,
#      12                                                         train_ratio=train_ratio,
#      13                                                         val_ratio=val_ratio)
#      14 #expect ~40s run on full Sen2_MTC data
#
# File D:\PyCharm 2024.2.1\Projects\COMPSCI-372-DUKE\Final Project\Dataloader.py:250, in prep_data_local(path, patch_size, stride, batch_size, train_ratio, val_ratio, return_loaders)
#     240 """
#     241 The full wrapper for local data preparation.
#     242 """
#     243 dataset_raw = SatImage_Dataloader(
#     244     route=path,
#     245     patch_size=patch_size,
#     246     stride=stride,
#     247     transform=None
#     248 )
# --> 250 mean, std = compute_global_stats(dataset_raw, batch_size=batch_size)
#     252 dataset_norm = SatImage_Dataloader(
#     253     route=path,
#     254     patch_size=patch_size,
#     255     stride=stride,
#     256     transform=Normalization(mean, std)
#     257 )
#     259 total = len(dataset_norm)
#
# File D:\PyCharm 2024.2.1\Projects\COMPSCI-372-DUKE\Final Project\Dataloader.py:216, in compute_global_stats(dataset, batch_size)
#     213 channel_sq_sum = None
#     214 total_pixels = 0
# --> 216 for batch in loader:
#     217     # use first cloudy view from the sequence: (B,T,C,H,W) -> (B,C,H,W)
#     218     x = batch["cloudy_seq"][0].double()
#     219     B, C, H, W = x.shape
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\utils\data\dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\utils\data\dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File D:\PyCharm 2024.2.1\Projects\COMPSCI-372-DUKE\Final Project\Dataloader.py:142, in SatImage_Dataloader.__getitem__(self, idx)
#     140 cloudy_list = []
#     141 for p in cloudy_paths:
# --> 142     c_np = self.load_tif(p)  # (H, W, C)
#     143     c_t  = torch.from_numpy(c_np.transpose(2, 0, 1))  # (C, H, W)
#     144     cloudy_list.append(c_t)
#
# File D:\PyCharm 2024.2.1\Projects\COMPSCI-372-DUKE\Final Project\Dataloader.py:125, in SatImage_Dataloader.load_tif(self, path)
#     124 def load_tif(self, path):
# --> 125     arr = tiff.imread(path)  # (H, W, C)
#     126     arr = np.array(arr, dtype=np.float32)
#     127     return arr
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\tifffile\tifffile.py:1176, in imread(files, selection, aszarr, key, series, level, squeeze, maxworkers, buffersize, mode, name, offset, size, pattern, axesorder, categories, imread, imreadargs, sort, container, chunkshape, chunkdtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, superres, out, out_inplace, _multifile, _useframes, **kwargs)
#    1173     files = files[0]
#    1175 if isinstance(files, str) or not isinstance(files, Sequence):
# -> 1176     with TiffFile(
#    1177         files,
#    1178         mode=mode,
#    1179         name=name,
#    1180         offset=offset,
#    1181         size=size,
#    1182         omexml=omexml,
#    1183         superres=superres,
#    1184         _multifile=_multifile,
#    1185         _useframes=_useframes,
#    1186         **is_flags,
#    1187     ) as tif:
#    1188         if aszarr:
#    1189             assert key is None or isinstance(key, int)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\tifffile\tifffile.py:4264, in TiffFile.__init__(self, file, mode, name, offset, size, omexml, superres, _multifile, _useframes, _parent, **is_flags)
#    4261     self._omexml = omexml
#    4262     self.is_ome = True
# -> 4264 fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#    4265 self._fh = fh
#    4266 self._multifile = True if _multifile is None else bool(_multifile)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\tifffile\tifffile.py:13444, in FileHandle.__init__(self, file, mode, name, offset, size)
#   13442 self._close = True
#   13443 self._lock = NullContext()
# > 13444 self.open()
#   13445 assert self._fh is not None
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\tifffile\tifffile.py:13463, in FileHandle.open(self)
#   13461 self._file = os.path.realpath(self._file)
#   13462 self._dir, self._name = os.path.split(self._file)
# > 13463 self._fh = open(self._file, self._mode, encoding=None)
#   13464 self._close = True
#   13465 self._offset = max(0, self._offset)
#
# KeyboardInterrupt:

# %%
for batch in train_loader:
    print(batch['cloudy_seq'].shape)
    print(batch['clean'].shape)
    x = batch['cloudy_seq'][0]
    print(x.mean(), x.std())
    break
# Out:
# torch.Size([16, 3, 4, 128, 128])
# torch.Size([16, 4, 128, 128])
# tensor(-0.0653) tensor(0.5254)

# %%
import wrapped.model as model
importlib.reload(model)
import wrapped.utils as utils
importlib.reload(utils)
from wrapped.model import build_forward_model, backward_sampler

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_dict = build_forward_model(
    in_channels = 4,
    base_channels = 32,
    num_stages = 2,
    latent_dim = 128,
    T_cloud=3,
    T_diffusion=750,
    device=device
)
base_encoder = model_dict['base_encoder']
cloud_encoder = model_dict['cloud_encoder']
forwarder = model_dict['forwarder']
denoiser = model_dict['denoiser']

import wrapped.utils as utils
cloud_enc_count = utils.count_params(cloud_encoder)
forward_enc_count = utils.count_params(forwarder)
denoiser_count = utils.count_params(denoiser)
print(f"Total number of parameters: {cloud_enc_count+forward_enc_count+denoiser_count}")
# Out:
# Total number of parameters: 4292549

# %%
import wrapped.trainers as trainers
importlib.reload(trainers)
from wrapped.trainers import forward_trainer

epochs = 5
params = list(cloud_encoder.parameters()) + list(denoiser.parameters())
optimizer = torch.optim.AdamW(
    [
        {"params": denoiser.parameters(),      "lr": 1e-4},
        {"params": cloud_encoder.parameters(), "lr": 5e-5},
    ],
    weight_decay=1e-6,
)
forward_trainer(epochs=epochs,
                train_loader=train_loader,
                optimizer=optimizer,
                forwarder=forwarder,
                cloud_encoder=cloud_encoder,
                denoiser=denoiser,
                device=device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 15
#       6 params = list(cloud_encoder.parameters()) + list(denoiser.parameters())
#       7 optimizer = torch.optim.AdamW(
#       8     [
#       9         {"params": denoiser.parameters(),      "lr": 1e-4},
#    (...)
#      12     weight_decay=1e-6,
#      13 )
#      14 forward_trainer(epochs=epochs,
# ---> 15                 train_loader=train_loader,
#      16                 optimizer=optimizer,
#      17                 forwarder=forwarder,
#      18                 cloud_encoder=cloud_encoder,
#      19                 denoiser=denoiser,
#      20                 device=device)
#
# NameError: name 'train_loader' is not defined

# %%
cloud_encoder.eval()
denoiser.eval()
batch = next(iter(train_loader))
cloudy_seq = batch['cloudy_seq'].to(device)

x0 = backward_sampler(cloudy_seq=cloudy_seq,
                      cloud_encoder=cloud_encoder,
                      denoiser=denoiser,
                      forwarder=forwarder,
                      num_steps=750)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 cloud_encoder.eval()
#       2 denoiser.eval()
# ----> 3 batch = next(iter(train_loader))
#       4 cloudy_seq = batch['cloudy_seq'].to(device)
#       6 x0 = backward_sampler(cloudy_seq=cloudy_seq,
#       7                       cloud_encoder=cloud_encoder,
#       8                       denoiser=denoiser,
#       9                       forwarder=forwarder,
#      10                       num_steps=750)
#
# NameError: name 'train_loader' is not defined

# %%
from wrapped.utils import visualize
visualize(cloudy_seq=cloudy_seq,
          batch=batch,
          x0=x0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from wrapped.utils import visualize
# ----> 2 visualize(cloudy_seq=cloudy_seq,
#       3           batch=batch,
#       4           x0=x0)
#
# NameError: name 'cloudy_seq' is not defined
