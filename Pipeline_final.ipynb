# %%
path = "./Sen2_MTC_Mini"
patch_size = 128
stride = 128
batch_size = 16
train_ratio = .7
val_ratio = .15

train_loader, val_loader, test_loader = prep_data_local(path=path, 
                                                        patch_size=patch_size, 
                                                        stride=stride,
                                                        batch_size=batch_size,
                                                        train_ratio=train_ratio,
                                                        val_ratio=val_ratio)
#expect ~40s run on full Sen2_MTC data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 train_ratio = .7
#       6 val_ratio = .15
# ----> 8 train_loader, val_loader, test_loader = prep_data_local(path=path,
#       9                                                         patch_size=patch_size,
#      10                                                         stride=stride,
#      11                                                         batch_size=batch_size,
#      12                                                         train_ratio=train_ratio,
#      13                                                         val_ratio=val_ratio)
#
# File d:\Desktop\Duke 2025 Fall\CS 372\Final Project\Compsci372-Final_Project\wrapped\Dataloader.py:243, in prep_data_local(path, patch_size, stride, batch_size, train_ratio, val_ratio, return_loaders)
#     236 def prep_data_local(path,
#     237                     patch_size=128, stride=128, batch_size=16,
#     238                     train_ratio=.7, val_ratio=.15,
#     239                     return_loaders = True):
#     240     """
#     241     The full wrapper for local data preparation.
#     242     """
# --> 243     dataset_raw = SatImage_Dataloader(
#     244         route=path,
#     245         patch_size=patch_size,
#     246         stride=stride,
#     247         transform=None
#     248     )
#     250     mean, std = compute_global_stats(dataset_raw, batch_size=batch_size)
#     252     dataset_norm = SatImage_Dataloader(
#     253         route=path,
#     254         patch_size=patch_size,
#     255         stride=stride,
#     256         transform=Normalization(mean, std)
#     257     )
#
# File d:\Desktop\Duke 2025 Fall\CS 372\Final Project\Compsci372-Final_Project\wrapped\Dataloader.py:55, in SatImage_Dataloader.__init__(self, route, patch_size, stride, center_crop, transform)
#      52 cloudy_pattern    = r"(.+?)_(\d+)_(\d+)\.tif"  # match: <tile>_<n>_<k>.tif
#      53 cloudless_pattern = r"(.+?)_(\d+)\.tif"        # match: <tile>_<n>.tif
# ---> 55 for tile_name in sorted(os.listdir(route)):
#      56     tile_path = os.path.join(route, tile_name)
#      57     cloud_dir = os.path.join(tile_path, "cloud")
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: './Sen2_MTC_Mini'

# %%
for batch in train_loader:
    print(batch['cloudy_seq'].shape)
    print(batch['clean'].shape)
    x = batch['cloudy_seq'][0]
    print(x.mean(), x.std())
    break
# Out:
# torch.Size([16, 3, 4, 128, 128])
# torch.Size([16, 4, 128, 128])
# tensor(-0.0653) tensor(0.5254)

# %%
import wrapped.model as model
importlib.reload(model)
import wrapped.utils as utils
importlib.reload(utils)
from wrapped.model import build_forward_model, backward_sampler

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_dict = build_forward_model(
    in_channels = 4,
    base_channels = 32,
    num_stages = 2,
    latent_dim = 128,
    T_cloud=3,
    T_diffusion=750,
    device=device
)
base_encoder = model_dict['base_encoder']
cloud_encoder = model_dict['cloud_encoder']
forwarder = model_dict['forwarder']
denoiser = model_dict['denoiser']

import wrapped.utils as utils
cloud_enc_count = utils.count_params(cloud_encoder)
forward_enc_count = utils.count_params(forwarder)
denoiser_count = utils.count_params(denoiser)
print(f"Total number of parameters: {cloud_enc_count+forward_enc_count+denoiser_count}")
# Out:
# Total number of parameters: 4292549

# %%
import wrapped.trainers as trainers
importlib.reload(trainers)
from wrapped.trainers import forward_trainer

epochs = 5
params = list(cloud_encoder.parameters()) + list(denoiser.parameters())
optimizer = torch.optim.AdamW(
    [
        {"params": denoiser.parameters(),      "lr": 1e-4},
        {"params": cloud_encoder.parameters(), "lr": 5e-5},
    ],
    weight_decay=1e-6,
)
forward_trainer(epochs=epochs,
                train_loader=train_loader,
                optimizer=optimizer,
                forwarder=forwarder,
                cloud_encoder=cloud_encoder,
                denoiser=denoiser,
                device=device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 15
#       6 params = list(cloud_encoder.parameters()) + list(denoiser.parameters())
#       7 optimizer = torch.optim.AdamW(
#       8     [
#       9         {"params": denoiser.parameters(),      "lr": 1e-4},
#    (...)
#      12     weight_decay=1e-6,
#      13 )
#      14 forward_trainer(epochs=epochs,
# ---> 15                 train_loader=train_loader,
#      16                 optimizer=optimizer,
#      17                 forwarder=forwarder,
#      18                 cloud_encoder=cloud_encoder,
#      19                 denoiser=denoiser,
#      20                 device=device)
#
# NameError: name 'train_loader' is not defined

# %%
cloud_encoder.eval()
denoiser.eval()
batch = next(iter(train_loader))
cloudy_seq = batch['cloudy_seq'].to(device)

x0 = backward_sampler(cloudy_seq=cloudy_seq,
                      cloud_encoder=cloud_encoder,
                      denoiser=denoiser,
                      forwarder=forwarder,
                      num_steps=750)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 cloud_encoder.eval()
#       2 denoiser.eval()
# ----> 3 batch = next(iter(train_loader))
#       4 cloudy_seq = batch['cloudy_seq'].to(device)
#       6 x0 = backward_sampler(cloudy_seq=cloudy_seq,
#       7                       cloud_encoder=cloud_encoder,
#       8                       denoiser=denoiser,
#       9                       forwarder=forwarder,
#      10                       num_steps=750)
#
# NameError: name 'train_loader' is not defined

# %%
from wrapped.utils import visualize
visualize(cloudy_seq=cloudy_seq,
          batch=batch,
          x0=x0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from wrapped.utils import visualize
# ----> 2 visualize(cloudy_seq=cloudy_seq,
#       3           batch=batch,
#       4           x0=x0)
#
# NameError: name 'cloudy_seq' is not defined
